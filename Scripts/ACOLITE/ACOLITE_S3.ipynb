# %%
import sys, os
user_home = os.path.expanduser("~")
sys.path.append(user_home+'/Documents/Git/acolite') # update to where acolite is saved on your harddrive
import acolite as ac

# %%
## set up
download_dir = 'c:/Users/ssharp/Documents/git/LE2022/Data/Sentinel3/S3_L1'
output_dir = 'c:/Users/ssharp/Documents/git/LE2022/Data/Sentinel3/S3_L2_acolite'

## ROI for extraction and reprojection (S, W, N, E)
limit = [42.975101260529925, -89.5221791989459, 43.20072851621282, -89.26008675058664]

## date to query
# These are the dates for all the DESIS/PRISMA scenes we are using
#date = '2020-06-02'
#date = '2020-12-25'
#date = '2021-06-05'
#date = '2021-06-11'
#date = '2021-06-15'
#date = '2021-08-15'
#date = '2021-09-05'
#date = '2021-11-02'
#date = '2021-12-13'
#date = '2022-05-13'
#date = '2022-06-02'
#date = '2022-06-16'
#date = '2022-06-23'
#date = '2022-07-27'
#date = '2022-08-31'
#date = '2022-10-10'

# ALSO PROCESS AVIRIS SCENES to confirm ISOFIT correction is good
date = '2022-08-22'
#date = '2022-08-31' #already have a DESIS/PRISMA scene from that date

## example point location
# These are the coordinates of the buoy
st_lat = 43.0995
st_lon = -89.4045
# These are the coordinates that Quinten used
#st_lat = 43.09062957763672
#st_lon = -89.46370697021484

# %%
## query CDSE database
urls, scenes = ac.cdse.query(
    roi='POINT ({} {})'.format(st_lon, st_lat),
    collection = "SENTINEL-3", 
    start_date = date, end_date = date)
# Out:
# Using default product OL_1_EFR___ for SENTINEL-3
# Found 2 total scenes

# %%
## download scenes to local directory
local_scenes = ac.cdse.download(urls, scenes=scenes, output = download_dir)
# Make sure you save your login to the acolite config file 
# this is the website where you make an account:
# https://dataspace.copernicus.eu/
# Out:
# Downloading 2 scenes
# Local copy of S3B_OL_1_EFR____20220822T162143_20220822T162443_20220822T181258_0179_069_311_2160_PS2_O_NR_002.SEN3 exists
# Local copy of S3B_OL_1_EFR____20220822T162143_20220822T162443_20220823T084739_0179_069_311_2160_PS2_O_NT_002.SEN3 exists

# %%
## set up run settings
## parameters that are not set will be set to defaults
settings = {}
settings['inputfile'] = local_scenes[0]
settings['limit'] = limit
settings['output'] = output_dir

## since we have a rather small ROI, a single aot estimate is reasonable
settings['dsf_aot_estimate'] = 'fixed'
settings['dsf_spectrum_option'] = 'darkest'

## reprojection of S3 from swath geometry to UTM projection
settings['reproject_before_ac'] = True
settings['output_projection'] = True
settings['limit_buffer'] = 0.1 ## extra buffer around limit

settings['l2w_parameters'] = 'rhow_*'

## run acolite :-)
ac.acolite.acolite_run(settings)
# Out:
# Running ACOLITE processing - Generic GitHub Clone c2023-11-15T12:59:53
# Python - win32 - 3.11.6 | packaged by conda-forge | (main, Oct  3 2023, 10:29:11) [MSC v.1935 64 bit (AMD64)]
# Platform - Windows 10 - AMD64 - 10.0.19045
# Run ID - 20231201_092505
# Identified c:/Users/ssharp/Documents/git/LE2022/Data/Sentinel3/S3_L1/S3B_OL_1_EFR____20220822T162143_20220822T162443_20220822T181258_0179_069_311_2160_PS2_O_NR_002.SEN3 as Sentinel-3 type
# Starting conversion of 1 scenes
# Applying limit buffer 0.1
# Old limit: [42.975101260529925, -89.5221791989459, 43.20072851621282, -89.26008675058664]
# New limit: (42.875101260529924, -89.6221791989459, 43.30072851621282, -89.16008675058664)
# Oa01_radiance (165, 256)
# Applying gain 0.99458 for Oa01_radiance
# Oa02_radiance (165, 256)
# Applying gain 0.99010 for Oa02_radiance
# Oa03_radiance (165, 256)
# Applying gain 0.99221 for Oa03_radiance
# Oa04_radiance (165, 256)
# Applying gain 0.98620 for Oa04_radiance
# Oa05_radiance (165, 256)
# Applying gain 0.98899 for Oa05_radiance
# Oa06_radiance (165, 256)
# Applying gain 0.99114 for Oa06_radiance
# Oa07_radiance (165, 256)
# Applying gain 0.99769 for Oa07_radiance
# Oa08_radiance (165, 256)
# Applying gain 0.99684 for Oa08_radiance
# Oa09_radiance (165, 256)
# Applying gain 0.99716 for Oa09_radiance
# Oa10_radiance (165, 256)
# Applying gain 0.99802 for Oa10_radiance
# Oa11_radiance (165, 256)
# Applying gain 0.99782 for Oa11_radiance
# Oa12_radiance (165, 256)
# Applying gain 1.00163 for Oa12_radiance
# Oa13_radiance (165, 256)
# Applying gain 1.00000 for Oa13_radiance
# Oa14_radiance (165, 256)
# Applying gain 1.00000 for Oa14_radiance
# Oa15_radiance (165, 256)
# Applying gain 1.00000 for Oa15_radiance
# Oa16_radiance (165, 256)
# Applying gain 1.00259 for Oa16_radiance
# Oa17_radiance (165, 256)
# Applying gain 1.00000 for Oa17_radiance
# Oa18_radiance (165, 256)
# Applying gain 1.00089 for Oa18_radiance
# Oa19_radiance (165, 256)
# Applying gain 1.00000 for Oa19_radiance
# Oa20_radiance (165, 256)
# Applying gain 1.00000 for Oa20_radiance
# Oa21_radiance (165, 256)
# Applying gain 0.94064 for Oa21_radiance
# Getting ancillary data for 2022-08-22T16:21:43.479064+00:00 -89.417E 43.088N
# Downloading file GMAO_MERRA2.20220822T160000.MET.nc
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/GMAO_MERRA2.20220822T160000.MET.nc
# Finished downloading file GMAO_MERRA2.20220822T160000.MET.nc
# Downloading file GMAO_MERRA2.20220822T170000.MET.nc
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/GMAO_MERRA2.20220822T170000.MET.nc
# Finished downloading file GMAO_MERRA2.20220822T170000.MET.nc
# No ozone file found for 2022-08-22 16:21:43.479064+00:00
# No NCEP files found for 2022-08-22 16:21:43.479064+00:00
# current uoz: 0.30 uwv: 1.50 pressure: 1013.25
# Running smile correction
# 2023-12-01T09:25:10 - Gas correction before smile correction
# 2023-12-01T09:25:10 - Smile correction for band Oa01 400.0 nm
# 2023-12-01T09:25:10 - Smile correction - bounding bands Oa01/Oa02
# 2023-12-01T09:25:10 - Smile correction for band Oa02 412.5 nm
# 2023-12-01T09:25:10 - Smile correction - bounding bands Oa01/Oa03
# 2023-12-01T09:25:10 - Smile correction for band Oa03 442.5 nm
# 2023-12-01T09:25:10 - Smile correction - bounding bands Oa02/Oa04
# 2023-12-01T09:25:10 - Smile correction for band Oa04 490.0 nm
# 2023-12-01T09:25:10 - Smile correction - bounding bands Oa03/Oa05
# 2023-12-01T09:25:10 - Smile correction for band Oa05 510.0 nm
# 2023-12-01T09:25:10 - Smile correction - bounding bands Oa04/Oa06
# 2023-12-01T09:25:10 - Smile correction for band Oa06 560.0 nm
# 2023-12-01T09:25:10 - Smile correction - bounding bands Oa05/Oa07
# 2023-12-01T09:25:10 - Smile correction for band Oa07 620.0 nm
# 2023-12-01T09:25:10 - Smile correction - bounding bands Oa06/Oa08
# 2023-12-01T09:25:10 - Smile correction for band Oa08 665.0 nm
# 2023-12-01T09:25:10 - Smile correction - bounding bands Oa07/Oa09
# 2023-12-01T09:25:10 - Smile correction for band Oa09 673.75 nm
# 2023-12-01T09:25:10 - Smile correction - bounding bands Oa08/Oa09
# 2023-12-01T09:25:10 - Smile correction for band Oa10 681.25 nm
# 2023-12-01T09:25:10 - Smile correction for band Oa11 708.75 nm
# 2023-12-01T09:25:10 - Smile correction - bounding bands Oa11/Oa12
# 2023-12-01T09:25:10 - Smile correction for band Oa12 753.75 nm
# 2023-12-01T09:25:10 - Smile correction - bounding bands Oa11/Oa12
# 2023-12-01T09:25:10 - Smile correction for band Oa13 761.25 nm
# 2023-12-01T09:25:10 - Smile correction for band Oa14 764.375 nm
# 2023-12-01T09:25:10 - Smile correction for band Oa15 767.5 nm
# 2023-12-01T09:25:10 - Smile correction for band Oa16 778.75 nm
# 2023-12-01T09:25:10 - Smile correction - bounding bands Oa16/Oa17
# 2023-12-01T09:25:10 - Smile correction for band Oa17 865.0 nm
# 2023-12-01T09:25:10 - Smile correction - bounding bands Oa16/Oa18
# 2023-12-01T09:25:10 - Smile correction for band Oa18 885.0 nm
# 2023-12-01T09:25:10 - Smile correction - bounding bands Oa17/Oa18
# 2023-12-01T09:25:10 - Smile correction for band Oa19 900.0 nm
# 2023-12-01T09:25:10 - Smile correction for band Oa20 940.0 nm
# 2023-12-01T09:25:10 - Smile correction for band Oa21 1020.0 nm
# 2023-12-01T09:25:10 - Smile correction - bounding bands Oa18/Oa21
# 2023-12-01T09:25:10 - Gas correction restored after smile correction
# Writing geolocation
# Writing geometry
# Writing TOA reflectance
# 2023-12-01T09:25:11 - Reading TOA data for 401 nm
# Converting bands: Wrote rhot_401 ((165, 256))
# 2023-12-01T09:25:11 - Reading TOA data for 412 nm
# Converting bands: Wrote rhot_412 ((165, 256))
# 2023-12-01T09:25:11 - Reading TOA data for 443 nm
# Converting bands: Wrote rhot_443 ((165, 256))
# 2023-12-01T09:25:11 - Reading TOA data for 490 nm
# Converting bands: Wrote rhot_490 ((165, 256))
# 2023-12-01T09:25:11 - Reading TOA data for 510 nm
# Converting bands: Wrote rhot_510 ((165, 256))
# 2023-12-01T09:25:11 - Reading TOA data for 560 nm
# Converting bands: Wrote rhot_560 ((165, 256))
# 2023-12-01T09:25:11 - Reading TOA data for 620 nm
# Converting bands: Wrote rhot_620 ((165, 256))
# 2023-12-01T09:25:11 - Reading TOA data for 665 nm
# Converting bands: Wrote rhot_665 ((165, 256))
# 2023-12-01T09:25:11 - Reading TOA data for 674 nm
# Converting bands: Wrote rhot_674 ((165, 256))
# 2023-12-01T09:25:11 - Reading TOA data for 681 nm
# Converting bands: Wrote rhot_681 ((165, 256))
# 2023-12-01T09:25:11 - Reading TOA data for 709 nm
# Converting bands: Wrote rhot_709 ((165, 256))
# 2023-12-01T09:25:11 - Reading TOA data for 754 nm
# Converting bands: Wrote rhot_754 ((165, 256))
# 2023-12-01T09:25:11 - Reading TOA data for 762 nm
# Converting bands: Wrote rhot_762 ((165, 256))
# 2023-12-01T09:25:11 - Reading TOA data for 765 nm
# Converting bands: Wrote rhot_765 ((165, 256))
# 2023-12-01T09:25:11 - Reading TOA data for 768 nm
# Converting bands: Wrote rhot_768 ((165, 256))
# 2023-12-01T09:25:11 - Reading TOA data for 779 nm
# Converting bands: Wrote rhot_779 ((165, 256))
# 2023-12-01T09:25:11 - Reading TOA data for 865 nm
# Converting bands: Wrote rhot_865 ((165, 256))
# 2023-12-01T09:25:11 - Reading TOA data for 884 nm
# Converting bands: Wrote rhot_884 ((165, 256))
# 2023-12-01T09:25:11 - Reading TOA data for 899 nm
# Converting bands: Wrote rhot_899 ((165, 256))
# 2023-12-01T09:25:11 - Reading TOA data for 939 nm
# Converting bands: Wrote rhot_939 ((165, 256))
# 2023-12-01T09:25:11 - Reading TOA data for 1016 nm
# Converting bands: Wrote rhot_1016 ((165, 256))
# Conversion took 5.5 seconds
# Created c:/Users/ssharp/Documents/git/LE2022/Data/Sentinel3/S3_L2_acolite/S3B_OLCI_2022_08_22_16_21_43_L1R.nc
# C:\Users\ssharp/Documents/Git/acolite\acolite\output\project_acolite_netcdf.py:22: UserWarning: XArray, dask, and/or zarr not found, XArrayBilinearResampler won't be available.
#   from pyresample.bilinear import NumpyBilinearResampler
# Using default grid size: 300.0x-300.0metres
# 16 32616
# Setting up target projection.
# (294000.0, 316800.0) (4785900.0, 4761300.0)
# 76 82
# Reading lon 165x256
# Reading lat 165x256
# Reading vaa 165x256
# Reading vza 165x256
# Reading saa 165x256
# Reading sza 165x256
# Reading pressure 165x256
# Reading raa 165x256
# Reading rhot_401 165x256
# Reading rhot_412 165x256
# Reading rhot_443 165x256
# Reading rhot_490 165x256
# Reading rhot_510 165x256
# Reading rhot_560 165x256
# Reading rhot_620 165x256
# Reading rhot_665 165x256
# Reading rhot_674 165x256
# Reading rhot_681 165x256
# Reading rhot_709 165x256
# Reading rhot_754 165x256
# Reading rhot_762 165x256
# Reading rhot_765 165x256
# Reading rhot_768 165x256
# Reading rhot_779 165x256
# Reading rhot_865 165x256
# Reading rhot_884 165x256
# Reading rhot_899 165x256
# Reading rhot_939 165x256
# Reading rhot_1016 165x256
# Projecting datasets 165x256x29 to EPSG:32616 76x82x29
# C:\Users\ssharp\Anaconda3\envs\acolite\Lib\site-packages\pyproj\crs\crs.py:1293: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# Reprojection of 29 datasets took 0.1 seconds
# Writing lon 82x76
# Writing lat 82x76
# Writing vaa 82x76
# Writing vza 82x76
# Writing saa 82x76
# Writing sza 82x76
# Writing pressure 82x76
# Writing raa 82x76
# Writing rhot_401 82x76
# Writing rhot_412 82x76
# Writing rhot_443 82x76
# Writing rhot_490 82x76
# Writing rhot_510 82x76
# Writing rhot_560 82x76
# Writing rhot_620 82x76
# Writing rhot_665 82x76
# Writing rhot_674 82x76
# Writing rhot_681 82x76
# Writing rhot_709 82x76
# Writing rhot_754 82x76
# Writing rhot_762 82x76
# Writing rhot_765 82x76
# Writing rhot_768 82x76
# Writing rhot_779 82x76
# Writing rhot_865 82x76
# Writing rhot_884 82x76
# Writing rhot_899 82x76
# Writing rhot_939 82x76
# Writing rhot_1016 82x76
# Wrote c:/Users/ssharp/Documents/git/LE2022/Data/Sentinel3/S3_L2_acolite/S3B_OLCI_2022_08_22_16_21_43_L1R_projected.nc
# Wrote c:/Users/ssharp/Documents/git/LE2022/Data/Sentinel3/S3_L2_acolite/S3B_OLCI_2022_08_22_16_21_43_L1R_projected_rgb_rhot.png
# Running acolite for c:/Users/ssharp/Documents/git/LE2022/Data/Sentinel3/S3_L2_acolite/S3B_OLCI_2022_08_22_16_21_43_L1R_projected.nc
# Getting ancillary data for 2022-08-22T16:21:43.479064+00:00 -89.393E 43.091N
# Downloading file GMAO_MERRA2.20220822T160000.MET.nc
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/GMAO_MERRA2.20220822T160000.MET.nc
# Finished downloading file GMAO_MERRA2.20220822T160000.MET.nc
# Downloading file GMAO_MERRA2.20220822T170000.MET.nc
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/GMAO_MERRA2.20220822T170000.MET.nc
# Finished downloading file GMAO_MERRA2.20220822T170000.MET.nc
# No ozone file found for 2022-08-22T16:21:43.479064+00:00
# No NCEP files found for 2022-08-22T16:21:43.479064+00:00
# default uoz: 0.30 uwv: 1.50 pressure: 1013.25
# current uoz: 0.30 uwv: 1.50 pressure: 1013.25
# Using DSF atmospheric correction
# Writing lon
# Wrote lon
# Writing lat
# Wrote lat
# Writing sza
# Wrote sza
# Writing vza
# Wrote vza
# Writing saa
# Wrote saa
# Writing vaa
# Wrote vaa
# Writing raa
# Wrote raa
# Loading LUTs ['ACOLITE-LUT-202110-MOD1', 'ACOLITE-LUT-202110-MOD2']
# Loading LUTs took 10.3 s
# Oa03 rhot_443
# Oa03 darkest 0.117
# S3B_OLCI/BOa03 ACOLITE-LUT-202110-MOD1 took 0.021s (StdLUT)
# S3B_OLCI/BOa03 ACOLITE-LUT-202110-MOD2 took 0.005s (StdLUT)
# Oa04 rhot_490
# Oa04 darkest 0.082
# S3B_OLCI/BOa04 ACOLITE-LUT-202110-MOD1 took 0.005s (StdLUT)
# S3B_OLCI/BOa04 ACOLITE-LUT-202110-MOD2 took 0.008s (StdLUT)
# Oa05 rhot_510
# Oa05 darkest 0.071
# S3B_OLCI/BOa05 ACOLITE-LUT-202110-MOD1 took 0.011s (StdLUT)
# S3B_OLCI/BOa05 ACOLITE-LUT-202110-MOD2 took 0.007s (StdLUT)
# Oa06 rhot_560
# Oa06 darkest 0.054
# S3B_OLCI/BOa06 ACOLITE-LUT-202110-MOD1 took 0.007s (StdLUT)
# S3B_OLCI/BOa06 ACOLITE-LUT-202110-MOD2 took 0.012s (StdLUT)
# Oa07 rhot_620
# Oa07 darkest 0.036
# S3B_OLCI/BOa07 ACOLITE-LUT-202110-MOD1 took 0.005s (StdLUT)
# S3B_OLCI/BOa07 ACOLITE-LUT-202110-MOD2 took 0.010s (StdLUT)
# Oa08 rhot_665
# Oa08 darkest 0.029
# S3B_OLCI/BOa08 ACOLITE-LUT-202110-MOD1 took 0.012s (StdLUT)
# S3B_OLCI/BOa08 ACOLITE-LUT-202110-MOD2 took 0.009s (StdLUT)
# Oa09 rhot_674
# Oa09 darkest 0.028
# S3B_OLCI/BOa09 ACOLITE-LUT-202110-MOD1 took 0.007s (StdLUT)
# S3B_OLCI/BOa09 ACOLITE-LUT-202110-MOD2 took 0.007s (StdLUT)
# Oa10 rhot_681
# Oa10 darkest 0.027
# S3B_OLCI/BOa10 ACOLITE-LUT-202110-MOD1 took 0.004s (StdLUT)
# S3B_OLCI/BOa10 ACOLITE-LUT-202110-MOD2 took 0.006s (StdLUT)
# Oa11 rhot_709
# Oa11 darkest 0.024
# S3B_OLCI/BOa11 ACOLITE-LUT-202110-MOD1 took 0.006s (StdLUT)
# S3B_OLCI/BOa11 ACOLITE-LUT-202110-MOD2 took 0.006s (StdLUT)
# Oa12 rhot_754
# Oa12 darkest 0.024
# S3B_OLCI/BOa12 ACOLITE-LUT-202110-MOD1 took 0.003s (StdLUT)
# S3B_OLCI/BOa12 ACOLITE-LUT-202110-MOD2 took 0.006s (StdLUT)
# Oa15 rhot_768
# Oa15 darkest 0.019
# S3B_OLCI/BOa15 ACOLITE-LUT-202110-MOD1 took 0.003s (StdLUT)
# S3B_OLCI/BOa15 ACOLITE-LUT-202110-MOD2 took 0.003s (StdLUT)
# Oa16 rhot_779
# Oa16 darkest 0.022
# S3B_OLCI/BOa16 ACOLITE-LUT-202110-MOD1 took 0.004s (StdLUT)
# S3B_OLCI/BOa16 ACOLITE-LUT-202110-MOD2 took 0.004s (StdLUT)
# Oa17 rhot_865
# Oa17 darkest 0.012
# S3B_OLCI/BOa17 ACOLITE-LUT-202110-MOD1 took 0.004s (StdLUT)
# S3B_OLCI/BOa17 ACOLITE-LUT-202110-MOD2 took 0.006s (StdLUT)
# Oa18 rhot_884
# Oa18 darkest 0.008
# S3B_OLCI/BOa18 ACOLITE-LUT-202110-MOD1 took 0.004s (StdLUT)
# S3B_OLCI/BOa18 ACOLITE-LUT-202110-MOD2 took 0.005s (StdLUT)
# Oa21 rhot_1016
# Oa21 darkest 0.010
# S3B_OLCI/BOa21 ACOLITE-LUT-202110-MOD1 took 0.005s (StdLUT)
# S3B_OLCI/BOa21 ACOLITE-LUT-202110-MOD2 took 0.005s (StdLUT)
# Choosing best fitting model: min_drmsd (2 bands)
# Computing RMSD for model ACOLITE-LUT-202110-MOD1
# Computing RMSD for model ACOLITE-LUT-202110-MOD1: 1.9250e-03
# Computing RMSD for model ACOLITE-LUT-202110-MOD2
# Computing RMSD for model ACOLITE-LUT-202110-MOD2: 1.9624e-03
# Selected model ACOLITE-LUT-202110-MOD1: aot 0.061, RMSD 1.92e-03
# Reshaping wind to 82x76
# use_revlut True
# Wrote rhot_401
# Computing surface reflectance Oa01 401 1.000
# Wrote rhos_401
# S3B_OLCI/BOa01 took 0.2s (RevLUT)
# Wrote rhot_412
# Computing surface reflectance Oa02 412 1.000
# Wrote rhos_412
# S3B_OLCI/BOa02 took 0.2s (RevLUT)
# Wrote rhot_443
# Computing surface reflectance Oa03 443 0.998
# Wrote rhos_443
# S3B_OLCI/BOa03 took 0.2s (RevLUT)
# Wrote rhot_490
# Computing surface reflectance Oa04 490 0.986
# Wrote rhos_490
# S3B_OLCI/BOa04 took 0.2s (RevLUT)
# Wrote rhot_510
# Computing surface reflectance Oa05 510 0.972
# Wrote rhos_510
# S3B_OLCI/BOa05 took 0.1s (RevLUT)
# Wrote rhot_560
# Computing surface reflectance Oa06 560 0.930
# Wrote rhos_560
# S3B_OLCI/BOa06 took 0.1s (RevLUT)
# Wrote rhot_620
# Computing surface reflectance Oa07 620 0.929
# Wrote rhos_620
# S3B_OLCI/BOa07 took 0.1s (RevLUT)
# Wrote rhot_665
# Computing surface reflectance Oa08 665 0.966
# Wrote rhos_665
# S3B_OLCI/BOa08 took 0.1s (RevLUT)
# Wrote rhot_674
# Computing surface reflectance Oa09 674 0.972
# Wrote rhos_674
# S3B_OLCI/BOa09 took 0.1s (RevLUT)
# Wrote rhot_681
# Computing surface reflectance Oa10 681 0.973
# Wrote rhos_681
# S3B_OLCI/BOa10 took 0.1s (RevLUT)
# Wrote rhot_709
# Computing surface reflectance Oa11 709 0.965
# Wrote rhos_709
# S3B_OLCI/BOa11 took 0.2s (RevLUT)
# Wrote rhot_754
# Computing surface reflectance Oa12 754 0.982
# Wrote rhos_754
# S3B_OLCI/BOa12 took 0.1s (RevLUT)
# Wrote rhot_762
# Band Oa13 at 762 nm has tgas < min_tgas_rho (0.42 < 0.80)
# Wrote rhot_765
# Band Oa14 at 765 nm has tgas < min_tgas_rho (0.66 < 0.80)
# Wrote rhot_768
# Computing surface reflectance Oa15 768 0.904
# Wrote rhos_768
# S3B_OLCI/BOa15 took 0.1s (RevLUT)
# Wrote rhot_779
# Computing surface reflectance Oa16 779 0.993
# Wrote rhos_779
# S3B_OLCI/BOa16 took 0.2s (RevLUT)
# Wrote rhot_865
# Computing surface reflectance Oa17 865 0.998
# Wrote rhos_865
# S3B_OLCI/BOa17 took 0.1s (RevLUT)
# Wrote rhot_884
# Computing surface reflectance Oa18 884 0.995
# Wrote rhos_884
# S3B_OLCI/BOa18 took 0.1s (RevLUT)
# Wrote rhot_899
# Band Oa19 at 899 nm has tgas < min_tgas_rho (0.74 < 0.80)
# Wrote rhot_939
# Band Oa20 at 939 nm has tgas < min_tgas_rho (0.31 < 0.80)
# Wrote rhot_1016
# Computing surface reflectance Oa21 1016 0.991
# Wrote rhos_1016
# S3B_OLCI/BOa21 took 0.1s (RevLUT)
# Wrote c:/Users/ssharp/Documents/git/LE2022/Data/Sentinel3/S3_L2_acolite/S3B_OLCI_2022_08_22_16_21_43_L2R_projected.nc
# Wrote c:/Users/ssharp/Documents/git/LE2022/Data/Sentinel3/S3_L2_acolite/S3B_OLCI_2022_08_22_16_21_43_L2R_projected_rgb_rhos.png
# L2W keeping data in memory: False
# ['rhot_401', 'rhot_412', 'rhot_443', 'rhot_490', 'rhot_510', 'rhot_560', 'rhot_620', 'rhot_665', 'rhot_674', 'rhot_681', 'rhot_709', 'rhot_754', 'rhot_762', 'rhot_765', 'rhot_768', 'rhot_779', 'rhot_865', 'rhot_884', 'rhot_899', 'rhot_939', 'rhot_1016'] [401, 412, 443, 490, 510, 560, 620, 665, 674, 681, 709, 754, 762, 765, 768, 779, 865, 884, 899, 939, 1016]
# ['rhos_401', 'rhos_412', 'rhos_443', 'rhos_490', 'rhos_510', 'rhos_560', 'rhos_620', 'rhos_665', 'rhos_674', 'rhos_681', 'rhos_709', 'rhos_754', 'rhos_768', 'rhos_779', 'rhos_865', 'rhos_884', 'rhos_1016'] [401, 412, 443, 490, 510, 560, 620, 665, 674, 681, 709, 754, 768, 779, 865, 884, 1016]
# Computing non water threshold mask.
# Computing non water threshold mask from rhot_1016 > 0.05.
# Computing cirrus mask.
# No suitable band found for cirrus masking.
# Computing TOA limit mask.
# Computing TOA limit mask from rhot_443 > 0.3.
# Computing TOA limit mask from rhot_490 > 0.3.
# Computing TOA limit mask from rhot_510 > 0.3.
# Computing TOA limit mask from rhot_560 > 0.3.
# Computing TOA limit mask from rhot_620 > 0.3.
# Computing TOA limit mask from rhot_665 > 0.3.
# Computing TOA limit mask from rhot_674 > 0.3.
# Computing TOA limit mask from rhot_681 > 0.3.
# Computing TOA limit mask from rhot_709 > 0.3.
# Computing TOA limit mask from rhot_754 > 0.3.
# Computing TOA limit mask from rhot_762 > 0.3.
# Computing TOA limit mask from rhot_765 > 0.3.
# Computing TOA limit mask from rhot_768 > 0.3.
# Computing TOA limit mask from rhot_779 > 0.3.
# Computing TOA limit mask from rhot_865 > 0.3.
# Computing TOA limit mask from rhot_884 > 0.3.
# Computing TOA limit mask from rhot_899 > 0.3.
# Computing TOA limit mask from rhot_939 > 0.3.
# Computing TOA limit mask from rhot_1016 > 0.3.
# Computing negative reflectance mask.
# Computing negative reflectance mask from rhos_443.
# Computing negative reflectance mask from rhos_490.
# Computing negative reflectance mask from rhos_510.
# Computing negative reflectance mask from rhos_560.
# Computing negative reflectance mask from rhos_620.
# Computing negative reflectance mask from rhos_665.
# Computing negative reflectance mask from rhos_674.
# Computing negative reflectance mask from rhos_681.
# Computing negative reflectance mask from rhos_709.
# Copying datasets from L2R.
# Copying lon, base dataset lon
# Writing lon
# Copying lat, base dataset lat
# Writing lat
# Copying rhow_401, base dataset rhos_401
# Writing rhow_401
# Copying rhow_412, base dataset rhos_412
# Writing rhow_412
# Copying rhow_443, base dataset rhos_443
# Writing rhow_443
# Copying rhow_490, base dataset rhos_490
# Writing rhow_490
# Copying rhow_510, base dataset rhos_510
# Writing rhow_510
# Copying rhow_560, base dataset rhos_560
# Writing rhow_560
# Copying rhow_620, base dataset rhos_620
# Writing rhow_620
# Copying rhow_665, base dataset rhos_665
# Writing rhow_665
# Copying rhow_674, base dataset rhos_674
# Writing rhow_674
# Copying rhow_681, base dataset rhos_681
# Writing rhow_681
# Copying rhow_709, base dataset rhos_709
# Writing rhow_709
# Copying rhow_754, base dataset rhos_754
# Writing rhow_754
# Copying rhow_768, base dataset rhos_768
# Writing rhow_768
# Copying rhow_779, base dataset rhos_779
# Writing rhow_779
# Copying rhow_865, base dataset rhos_865
# Writing rhow_865
# Copying rhow_884, base dataset rhos_884
# Writing rhow_884
# Copying rhow_1016, base dataset rhos_1016
# Writing rhow_1016
# Wrote c:/Users/ssharp/Documents/git/LE2022/Data/Sentinel3/S3_L2_acolite/S3B_OLCI_2022_08_22_16_21_43_L2W_projected.nc
# {0: {'input': 'c:/Users/ssharp/Documents/git/LE2022/Data/Sentinel3/S3_L1/S3B_OL_1_EFR____20220822T162143_20220822T162443_20220822T181258_0179_069_311_2160_PS2_O_NR_002.SEN3',
#   'l1r': ['c:/Users/ssharp/Documents/git/LE2022/Data/Sentinel3/S3_L2_acolite/S3B_OLCI_2022_08_22_16_21_43_L1R_projected.nc'],
#   'l1r_swath': ['c:/Users/ssharp/Documents/git/LE2022/Data/Sentinel3/S3_L2_acolite/S3B_OLCI_2022_08_22_16_21_43_L1R.nc'],
#   'l2r': ['c:/Users/ssharp/Documents/git/LE2022/Data/Sentinel3/S3_L2_acolite/S3B_OLCI_2022_08_22_16_21_43_L2R_projected.nc'],
#   'l2w': ['c:/Users/ssharp/Documents/git/LE2022/Data/Sentinel3/S3_L2_acolite/S3B_OLCI_2022_08_22_16_21_43_L2W_projected.nc']}}
